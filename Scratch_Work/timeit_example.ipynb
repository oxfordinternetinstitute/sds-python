# %% [markdown]
# # Timing functions to compare their efficiency
#
# This example shows how you use timeit to compare the efficiency of two different programs, each run many multiple times to assess this.
#
# See:
# https://medium.com/pythonhive/python-decorator-to-measure-the-execution-time-of-methods-fa04cb6bb36d

# %%
import time 

def timeit(method):
    def timed(*args, **kw):
        ts = time.time()
        result = method(*args, **kw)
        te = time.time()

        if 'log_time' in kw:
            name = kw.get('log_name', method.__name__.upper())
            kw['log_time'][name] = int((te - ts) * 1000)
        else:
            print('%r  %2.2f ms' % \
                  (method.__name__, (te - ts) * 1000))
        return result

    return timed

# %%
@timeit
def doubleNumber(number):
    try: 
        output == number*2
    except:
        output = None
    return output

@timeit
def doubleNumber2(number):
    try: 
        return number*2
    except:
        return none



doubleNumber(2)   
doubleNumber(10)
# Out:
# 'doubleNumber'  0.00 ms
# 'doubleNumber'  0.00 ms

# %%
# %timeit for x in range(100): doubleNumber(x)
# Out:
# 'doubleNumber'  0.00 ms
# 'doubleNumber'  0.00 ms
# 'doubleNumber'  0.00 ms
# 'doubleNumber'  0.00 ms
# 'doubleNumber'  0.00 ms
# 'doubleNumber'  0.00 ms
# 'doubleNumber'  0.00 ms
# 'doubleNumber'  0.00 ms
# 'doubleNumber'  0.00 ms
# 'doubleNumber'  0.00 ms
# 'doubleNumber'  0.00 ms
# 'doubleNumber'  0.00 ms
# 'doubleNumber'  0.00 ms
# 'doubleNumber'  0.00 ms
# 'doubleNumber'  0.00 ms
# 'doubleNumber'  0.00 ms
# 'doubleNumber'  0.00 ms
# 'doubleNumber'  0.00 ms
# 'doubleNumber'  0.00 ms
# 'doubleNumber'  0.00 ms
# 'doubleNumber'  0.00 ms
# 'doubleNumber'  0.00 ms
# 'doubleNumber'  0.00 ms
# 'doubleNumber'  0.00 ms
# 'doubleNumber'  0.00 ms
# 'doubleNumber'  0.00 ms
# 'doubleNumber'  0.00 ms
# 'doubleNumber'  0.00 ms
# 'doubleNumber'  0.00 ms
# 'doubleNumber'  0.00 ms
# 'doubleNumber'  0.00 ms
# 'doubleNumber'  0.00 ms
# 'doubleNumber'  0.00 ms
# 'doubleNumber'  0.00 ms
# 'doubleNumber'  0.00 ms
# 'doubleNumber'  0.00 ms
# 'doubleNumber'  0.00 ms
# 'doubleNumber'  0.00 ms
# ...
