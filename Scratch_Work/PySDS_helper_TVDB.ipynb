# %%
apikey = "E2P004YY1YUWSTWG"

  "token": "eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.eyJleHAiOjE1MzkyMTIzNTcsImlkIjoiTXVwcGV0IEVwaXNvZGVzIiwib3JpZ19pYXQiOjE1MzkxMjU5NTcsInVzZXJpZCI6NTEyODE4LCJ1c2VybmFtZSI6ImJlcm5pZS5ob2dhbjRhNSJ9.t4UEzGGyKR2Ou8cvAO4A0fbzjf8lZ-_VllVSXMC3u5iTcgTl0xI_BHzc4X9XKY1YDKkIrbr76YB688x9E__I1GsqGU331JimEkgcBBlUFA4pB2zsUblgHFPi8f5l87upGOtIArL0LZxnS3NIZi9n2zy7jLcAT8MxRJvbsCtRxFurbfsTKHTaGIEcxwHOvLASho2tZXk-HtyTg_bOMEfBhDWs5JfU902EFpFn65fwNGT_JPLEfYVdUApXkEx6jRkhGrMYzd8GoTvw1Mm_6XFW87ji20QW3EdqzLxGqAjaCug_mfrhqw3vJq-I9iQccj_pBQdiLZQTIw-1Tx1Ye3GuRA

# %%
import json 

filein = open("C:\\Users\\bernie\\Documents\\GitHub\\sds-python\\Scratch Work\\muppetEpisodes.json")
x = json.loads(filein.read())

# %%
from pandas.io.json import json_normalize

rtable = json_normalize(x["data"])
rtable
# Out:
#     absoluteNumber  airedEpisodeNumber  airedSeason  airedSeasonID director  \
# 0              1.0                  24            1           4221
# 1              2.0                  22            1           4221
# 2              3.0                   5            1           4221
# 3              4.0                   4            1           4221
# 4              5.0                   3            1           4221
# 5              6.0                   1            1           4221
# 6              7.0                   9            1           4221
# 7              8.0                   6            1           4221
# 8              9.0                  15            1           4221
# 9             10.0                  13            1           4221
# 10            11.0                   7            1           4221
# 11            12.0                   8            1           4221
# 12            13.0                  12            1           4221
# ...

# %%
for i in list(rtable.columns): print(i)
# Out:
# absoluteNumber
# airedEpisodeNumber
# airedSeason
# airedSeasonID
# director
# directors
# dvdDiscid
# dvdEpisodeNumber
# dvdSeason
# episodeName
# filename
# firstAired
# guestStars
# id
# imdbId
# language.episodeName
# language.overview
# lastUpdated
# lastUpdatedBy
# overview
# productionCode
# seriesId
# showUrl
# siteRating
# siteRatingCount
# thumbAdded
# thumbAuthor
# thumbHeight
# thumbWidth
# writers

# %%
x = rtable[['episodeName','airedEpisodeNumber','airedSeason']]
for i in range(1,5): 
    ntable = x[x['airedSeason'] == i]
    ntable.to_csv("muppet_show_season_%s.txt" % i)
